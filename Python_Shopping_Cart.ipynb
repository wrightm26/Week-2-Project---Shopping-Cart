# %%
#create a while statement to continue asking about the concert as long as the person is interested
#create a for loop to focus on the artist they want to hear
#ask which concert they would like to atten
    
def concert_cart():
    your_cart = {}
    total_cost = []
    keep_adding = True
    while keep_adding:
        add_cart = True
        while add_cart:
            artist_pick = input("\nWhich of the following concerts would you like to attend?\n\tPARTYNEXTDOOR\t$70\n\tTink\t\t$65.00\n\tGlorilla\t$95.00\n\tKodak Black\t$100.00\n").lower()
            while artist_pick not in {'partynextdoor','tink','glorilla','kodak black'}:
                artist_pick = input("\nThat option is not available!\nWhich of the following concerts would you like to attend?\n\tPARTYNEXTDOOR\t$70\n\tTink\t\t$65.00\n\tGlorilla\t$95.00\n\tKodak Black\t$100.00\n").lower()
            date_pick = input(f"\nWhich date would you like to attend {artist_pick.upper()}'s concert?\n\tFebruary 27\n\tFebruary 28\n\tMarch 1\n\tMarch 2\n").lower()
            while date_pick not in {'february 27','february 28','march 1','march 2'}:
                date_pick = input(f"\nThat option is not available!\nWhich date would you like to attend {artist_pick.upper()}'s concert?\\t 27\n\tFebruary 28\n\tMarch 1\n\tMarch 2\n").lower()
            time_pick = input(f"\nWhich of the following times would you like to attend {artist_pick.upper()}'s concert on {date_pick.upper()}?\n\t6:30\n\t7:30\n\t8:30\n\t9:30\n").lower()
            while time_pick not in {'6:30','7:30','8:30','9:30'}:
                time_pick = input(f"\nThat option is not available!\nWhich of the following times would you like to attend {artist_pick.upper()}'s concert on {date_pick.upper()}?\n\t6:30\n\t7:30\n\t8:30\n\t9:30\n").lower()
            quantity_pick = int(input(f"\nHow many ticket's would you like to purchase for {artist_pick.upper()}'s concert on {date_pick.upper()} at {time_pick}pm?\n(You can only purchase up to 10 tickets for each concert!)\n").lower())
            total_tickets = 0
            total_tickets = 0 + quantity_pick
            while quantity_pick not in range(0,11):
                quantity_pick = int(input(f"\nThat option is not available!\nHow many ticket's would you like to purchase for {artist_pick.upper()}'s concert on {date_pick.upper()} at {time_pick}pm?\n(You can only purchase up to 10 tickets for each concert!)\n").lower())
            edit_tickets = input(f"\nWould you like to add or delete some tickets? So far you have {total_tickets} tickets for this concert.\nEnter:\tAdd\tDelete\tNo\n").lower()
            while edit_tickets not in {'add','delete','no'}:
                edit_tickets = input(f"\nThat option is invalid.\nWould you like to add or delete some tickets? So far you have {total_tickets} tickets for this concert.\nEnter:\tAdd\tDelete\tOr\tNo\n").lower()
            while edit_tickets in {'add'}:
                add_tickets = int(input("\nHow many more tickets would you like to add to this concert?\n"))
                total_tickets = total_tickets + add_tickets
                edit_tickets = input(f"\nWould you like to add or delete some tickets? So far you have {total_tickets} tickets for this concert.\nEnter:\tAdd\tDelete\tOr\tNo\n").lower()
            while edit_tickets in {'delete'}:
                delete_tickets = int(input("\nHow many tickets would you like to delete from this concert?"))
                total_tickets = total_tickets - delete_tickets          
                edit_tickets = input(f"\nWould you like to add or delete some tickets? So far you have {total_tickets} tickets.\nEnter:\tAdd\tDelete\tOr\tNo\n").lower()
            
            
            if artist_pick not in your_cart:
                artist_pick = artist_pick.title()
                date_pick = date_pick.title()
                your_cart[artist_pick] = {
                    'Date' : date_pick,
                    'Time' : time_pick,
                    'Quantity of Tickets' : total_tickets
                        }

            cost = 0
            if artist_pick == 'Partynextdoor':
                cost += total_tickets * 70
            if artist_pick == 'Tink':
                cost += total_tickets * 65
            if artist_pick == 'Glorilla':
                cost += total_tickets * 95
            if artist_pick == 'Kodak Black':
                cost += total_tickets * 100

            total_cost.append(cost)
            
            totalcost = 0
            for num in range(0, len(total_cost)):
                totalcost = totalcost + total_cost[num] 
                total = 'Total Price'
                
                    
            print("\n\nYour Cart:\n")    
            for artist_pick, concert_info in your_cart.items():
                print(f"\nArtist: \n\n{artist_pick}\n\nConcert Info: \n\n{concert_info}\n\n")
            print(f"\nTotal Price: ${totalcost}.00")
                
            confirmation = input(f"\n\nWould you like to add a concert?\nEnter:\tAdd\tNo\n\n").lower()

            if confirmation == 'no':
                add_cart = False    
            if confirmation == 'add':
                continue
                
        next_step = True        
        while next_step:
            print("\n\nYour Cart:\n")    
            for artist_pick, concert_info in your_cart.items():
                print(f"\nArtist: \n\n{artist_pick}\n\nConcert Info:\n\n{concert_info}\n\n")
            print(f"\nTotal Price: ${totalcost}.00")
            confirmation = input(f"\n\nWould you like to delete a concert?If not continue.\nEnter:\tDelete\tNo\n\n").lower()
            if confirmation == 'delete':
                print("\n\nYour Cart:\n")    
                for artist_pick, concert_info in your_cart.items():
                    print(f"\nArtist: \n\n{artist_pick}\n\nConcert Info: \n\n{concert_info}\n\n")
                print(f"\nTotal Price: ${totalcost}.00")
                deleted_question = input("\nWhich concert would you like to delete?\n")
                if deleted_question == 'tink':
                    del your_cart['Tink']
                if deleted_question == 'kodak black':
                    del your_cart['Kodak Black']
                if deleted_question == 'glorilla':
                        del your_cart['Glorilla']
                if deleted_question == 'partynextdoor':
                    del your_cart['Partynextdoor']
                another_deleted = input("\nWould you like to delete another concert?\n").lower()
                if another_deleted == 'no': 
                    continue
                if another_deleted == 'yes':
                    deleted_question = input("\nWhich concert would you like to delete?\n").lower()
                           

            if confirmation == 'no':     
                
                print("\n\nThank you for purchasing the following tickets:\n")    
                   
                for artist_pick, concert_info in your_cart.items():
                    print(f"\nArtist: \n\n{artist_pick}\n\nConcert Info: \n\n{concert_info}\n\n")
                print(f"\nTotal Price: ${totalcost}.00")
                your_cart[total] = {'Price' : totalcost}
                keep_adding = False
                next_step = False
                break


        
add
concert_cart()
# Out:
# Which of the following concerts would you like to attend?
# 	PARTYNEXTDOOR	$70
# 	Tink		$65.00
# 	Glorilla	$95.00
# 	Kodak Black	$100.00
# tink
#
# Which date would you like to attend TINK's concert?
# 	February 27
# 	February 28
# 	March 1
# 	March 2
# march 2
#
# Which of the following times would you like to attend TINK's concert on MARCH 2?
# 	6:30
# 	7:30
# 	8:30
# 	9:30
# 9:30
#
# How many ticket's would you like to purchase for TINK's concert on MARCH 2 at 9:30pm?
# (You can only purchase up to 10 tickets for each concert!)
# 2
#
# Would you like to add or delete some tickets? So far you have 2 tickets for this concert.
# Enter:	Add	Delete	No
# no
#
#
# Your Cart:
#
#
# Artist:
#
# Tink
#
# Concert Info:
#
# {'Date': 'March 2', 'Time': '9:30', 'Quantity of Tickets': 2}
#
#
#
# Total Price: $130.00
#
#
# Would you like to add a concert?
# Enter:	Add	No
#
# add
#
# Which of the following concerts would you like to attend?
# 	PARTYNEXTDOOR	$70
# 	Tink		$65.00
# 	Glorilla	$95.00
# ...
